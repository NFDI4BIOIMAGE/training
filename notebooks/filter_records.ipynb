# %% [markdown]
# # Filtering records
# Our database can be retrieved as Pandas dataframe and then filtered. This is a bit tricky because types, tags, urls and authors are stored as lists of strings. This notebook demonstrate how to identify records with given tags AND of specified types.

# %%
import sys
sys.path.append("../scripts/")
from generate_link_lists import load_dataframe
import pandas as pd

# %% [markdown]
# First, we load all datasets as dataframe.

# %%
df = load_dataframe("../resources/")
df.head(2)
# Out:
#               authors                                               name  \
# 0  [Elisabeth Kugler]  Sharing Your Poster on Figshare: A Community G...
# 1  [Marcelo Zoccoler]  Running Deep-Learning Scripts in the BiA-PoL O...
#
#   proficiency_level                                               tags  \
# 0            novice                [Sharing, Research Data Management]
# 1        proficient  [Python, Artificial Intelligence, Bioimage Ana...
#
#           type                                                url    license  \
# 0  [Blog Post]  https://focalplane.biologists.com/2023/07/26/s...        NaN
# 1  [Blog Post]  https://biapol.github.io/blog/marcelo_zoccoler...  CC-BY-4.0
#
#   event_date event_location description  num_downloads publication_date  \
# 0        NaN            NaN         NaN            NaN              NaN
# 1        NaN            NaN         NaN            NaN              NaN
#
#   fingerprint author submission_date
# 0         NaN    NaN             NaN
# 1         NaN    NaN             NaN

# %% [markdown]
# At the time of executing this notebook, these many entries are stored:

# %%
len(df)
# Out:
# 549

# %% [markdown]
# In the following, we will identify all records that contain certain types and tags.

# %%
tags_to_find = ['Research Data Management']
types_to_find = ['Video']

filtered_df_all = df[df['tags'].notna() & df['type'].notna()].copy()  # Remove NaN entries first
filtered_df_all = filtered_df_all[filtered_df_all['tags'].apply(lambda x: all(tag in x for tag in tags_to_find))]
filtered_df_all = filtered_df_all[filtered_df_all['type'].apply(lambda x: all(typ in x for typ in types_to_find))]

filtered_df_all.head()
# Out:
#                                                authors  \
# 82   [Christian Schmidt, Michele Bortolomeazzi, Tom...
# 225                                    [Susanne Kunis]
# 296                                                NaN
# 297                                                NaN
# 348                                                NaN
#
#                                                   name  proficiency_level  \
# 82   I3D:bio's OMERO training material: Re-usable, ...  advanced beginner
# 225  Structuring of Data and Metadata in Bioimaging...  advanced beginner
# 296                                            RDM4mic  advanced beginner
# 297                                 FAIR BioImage Data  advanced beginner
# 348            Submitting data to the BioImage Archive  advanced beginner
#
#                                                   tags                 type  \
# 82   [OMERO, Research Data Management, Nfdi4Bioimag...      [Slides, Video]
# 225          [Nfdi4Bioimage, Research Data Management]              [Video]
# 296                  [Research Data Management, OMERO]  [Collection, Video]
# 297  [Research Data Management, Fair, Bioimage Anal...  [Collection, Video]
# 348                         [Research Data Management]    [Tutorial, Video]
#
#                                                    url    license event_date  \
# 82   [https://zenodo.org/records/8323588, https://w...  CC-BY-4.0        NaN
# 225  [https://zenodo.org/record/7018929, https://do...  CC-BY-4.0        NaN
# 296                 [https://www.youtube.com/@RDM4mic]    UNKNOWN        NaN
# 297  [https://www.youtube.com/watch?v=8zd4KTy-oYI&l...  CC-BY-4.0        NaN
# 348     https://www.ebi.ac.uk/bioimage-archive/submit/    CC0-1.0        NaN
#
#     event_location                                        description  \
# 82             NaN  The open-source software OME Remote Objects (O...
# 225            NaN  guided walkthrough of poster at https://doi.or...
# 296            NaN                                                NaN
# 297            NaN                                                NaN
# 348            NaN  To submit, you’ll need to register an account,...
#
#      num_downloads publication_date fingerprint author submission_date
# 82          3717.0       2023-11-13         NaN    NaN             NaN
# 225           26.0       2022-08-24         NaN    NaN             NaN
# 296            NaN              NaN         NaN    NaN             NaN
# 297            NaN              NaN         NaN    NaN             NaN
# 348            NaN              NaN         NaN    NaN             NaN

# %%
for u in filtered_df_all["url"]:
    print(u)
# Out:
# ['https://zenodo.org/records/8323588', 'https://www.youtube.com/playlist?list=PL2k-L-zWPoR7SHjG1HhDIwLZj0MB_stlU', 'https://doi.org/10.5281/zenodo.8323588']
# ['https://zenodo.org/record/7018929', 'https://doi.org/10.5281/zenodo.7018929']
# ['https://www.youtube.com/@RDM4mic']
# ['https://www.youtube.com/watch?v=8zd4KTy-oYI&list=PLW-oxncaXRqU4XqduJzwFHvWLF06PvdVm']
# https://www.ebi.ac.uk/bioimage-archive/submit/

# %%
print()
